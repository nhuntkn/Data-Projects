# %%
import pandas as pd
import numpy as np
import requests
import io

# %%
url = "https://storage.googleapis.com/aus-road-deaths-data-engineering-project/bitre_fatalities_feb2026.csv"
response = requests.get(url)
df = pd.read_csv(io.StringIO(response.text), sep = ',', header = 4)

# %%
df.head()
# Out:
#         Crash ID State  Month  Year   Dayweek      Time Crash Type  \
# 0  5201106170079    WA      6  2011    Friday  22:30:00     Single
# 1  4201105140046    SA      5  2011  Saturday  14:11:00     Single
# 2  1199410070402   NSW     10  1994    Friday  18:00:00   Multiple
# 3  3201212280255   QLD     12  2012    Friday  21:00:00   Multiple
# 4  3201110220178   QLD     10  2011  Saturday  13:00:00   Multiple
#
#   Bus Involvement Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# 0              No                            No                            No
# 1              No                            No                            No
# 2              No                            -9                            No
# 3              No                            No                            No
# 4              No                            No                            No
#
#    Speed Limit         Road User  Gender  Age National Remoteness Areas 2021  \
# 0           70            Driver    Male   46                        Unknown
# 1          100            Driver  Female   19                        Unknown
# 2           60            Driver  Female   35                        Unknown
# 3          100         Passenger  Female   38                        Unknown
# 4           60  Motorcycle rider    Male   28                        Unknown
#
#   SA4 Name 2021 National LGA Name 2021 National Road Type Christmas Period  \
# 0       Unknown                Unknown            Unknown               No
# 1       Unknown                Unknown            Unknown               No
# 2       Unknown                Unknown            Unknown               No
# 3       Unknown                Unknown            Unknown              Yes
# 4       Unknown                Unknown            Unknown               No
#
#   Easter Period
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58389 entries, 0 to 58388
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Crash ID                        58389 non-null  int64
#  1   State                           58389 non-null  object
#  2   Month                           58389 non-null  int64
#  3   Year                            58389 non-null  int64
#  4   Dayweek                         58389 non-null  object
#  5   Time                            58389 non-null  object
#  6   Crash Type                      58389 non-null  object
#  7   Bus Involvement                 58389 non-null  object
#  8   Heavy Rigid Truck Involvement   58389 non-null  object
#  9   Articulated Truck Involvement   58389 non-null  object
#  10  Speed Limit                     58389 non-null  int64
#  11  Road User                       58389 non-null  object
#  12  Gender                          58389 non-null  object
#  13  Age                             58389 non-null  int64
#  14  National Remoteness Areas 2021  58389 non-null  object
#  15  SA4 Name 2021                   58389 non-null  object
#  16  National LGA Name 2021          58389 non-null  object
#  17  National Road Type              58389 non-null  object
#  18  Christmas Period                58389 non-null  object
#  19  Easter Period                   58389 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 8.9+ MB

# %% [markdown]
# ## Tranfomation

# %% [markdown]
# **1. Create "Time of day" column**

# %%
df['Time'] = df['Time'].str.strip()

temp_dt = pd.to_datetime(df['Time'], format = '%H:%M:%S', errors = 'coerce')
time_hour = temp_dt.dt.hour

time_bins = [0, 6, 9, 15, 18, 24]
labels = ['Late Night', 'Morning Peak', 'Midday', 'Afternoon Peak', 'Evening']

df['Time of Day'] = pd.cut(time_hour, bins = time_bins, labels = labels, right = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['Time'] = df['Time'].str.strip()
#       3 temp_dt = pd.to_datetime(df['Time'], format = '%H:%M:%S', errors = 'coerce')
#       4 time_hour = temp_dt.dt.hour
#
# NameError: name 'df' is not defined

# %% [markdown]
# **2. Convert Time into datetime type**

# %%
df['Time'] = temp_dt.dt.strftime('%H:%M:%S')

# %% [markdown]
# **3. Handle the '-9' as missing/unknown values**

# %% [markdown]
# Change '-9' in 'Involvement' columns to 'Unknown'

# %%
involvement_cols = ['Bus Involvement',
                    'Heavy Rigid Truck Involvement',
                    'Articulated Truck Involvement']

for col in involvement_cols:

    #Convert to string first to ensure matching
    df[col] = df[col].str.strip()

    #Replace -9 with Unknown
    df[col] = df[col].replace('-9', 'Unknown')

# %% [markdown]
# Change '-9' in 'Age' column to NaN

# %%
number_cols = ['Age', 'Speed Limit']

for col in number_cols:
    df[col] = df[col].replace(-9, np.nan)

# %% [markdown]
# **4. Remove duplicates**

# %% [markdown]
# I only remove rows where every single column is the same

# %%
df = df.drop_duplicates()

# %% [markdown]
# **5. Create "Holiday Flag" and "Weekend Flag" columns**

# %% [markdown]
# This column uses Yes/No as values to indicate if the crash happened on holiday

# %%
df['Holiday Flag'] = df.apply(lambda x : 'Y'
                        if str(x['Christmas Period']).lower() == 'yes'
                        or str(x['Easter Period']).lower() == 'yes'
                        else 'N', axis = 1)

df['Weekend Flag'] = df.apply(lambda x: 'Y'
                        if str(x['Dayweek']).lower() == 'saturday'
                        or str(x['Dayweek']).lower() == 'sunday'
                        else 'N', axis = 1)

# %% [markdown]
# **6. Create "Age Group" column**

# %%
bins = [0, 16, 25, 39, 59, 74, 120]
labels = ['0-15', '16-24', '25-39', '40-59', '60-74', '75+']

df['Age Group'] = pd.cut(df['Age'], bins = bins, labels = labels, right = True)

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# **1. Create dim_date table**

# %%
dim_date = df[['Month', 'Year', 'Time', 'Time of Day', 'Holiday Flag', 'Weekend Flag']].drop_duplicates().reset_index(drop = True)
dim_date.insert(0, 'Date ID', dim_date.index)

dim_date.head()
# Out:
#    Date ID  Month  Year      Time Time of Day Holiday Flag Weekend Flag
# 0        0      6  2011  22:30:00     Evening            N            N
# 1        1      5  2011  14:11:00      Midday            N            Y
# 2        2     10  1994  18:00:00     Evening            N            N
# 3        3     12  2012  21:00:00     Evening            Y            N
# 4        4     10  2011  13:00:00      Midday            N            Y

# %% [markdown]
# **2. Create dim_location table**

# %%
dim_location = df[['State', 'National Road Type', 'National Remoteness Areas 2021', 'SA4 Name 2021', 'National LGA Name 2021']].drop_duplicates().reset_index(drop = True)
dim_location.insert(0, 'Location ID', dim_location.index)

dim_location.head()
# Out:
#    Location ID State National Road Type National Remoteness Areas 2021  \
# 0            0    WA            Unknown                        Unknown
# 1            1    SA            Unknown                        Unknown
# 2            2   NSW            Unknown                        Unknown
# 3            3   QLD            Unknown                        Unknown
# 4            4   VIC            Unknown                        Unknown
#
#   SA4 Name 2021 National LGA Name 2021
# 0       Unknown                Unknown
# 1       Unknown                Unknown
# 2       Unknown                Unknown
# 3       Unknown                Unknown
# 4       Unknown                Unknown

# %% [markdown]
# **3. Create dim_person table**

# %%
dim_person = df[['Gender', 'Age Group', 'Road User']].drop_duplicates().reset_index(drop = True)
dim_person.insert(0, 'Person ID', dim_person.index)

dim_person.head()
# Out:
#    Person ID  Gender Age Group         Road User
# 0          0    Male     40-59            Driver
# 1          1  Female     16-24            Driver
# 2          2  Female     25-39            Driver
# 3          3  Female     25-39         Passenger
# 4          4    Male     25-39  Motorcycle rider

# %% [markdown]
# **4. Create dim_scenario table**

# %%
dim_scenario = df[['Crash Type', 'Speed Limit', 'Bus Involvement', 'Heavy Rigid Truck Involvement', 'Articulated Truck Involvement']].drop_duplicates().reset_index(drop = True)
dim_scenario.insert(0, 'Scenario ID', dim_scenario.index)

dim_scenario.head()
# Out:
#    Scenario ID Crash Type  Speed Limit Bus Involvement  \
# 0            0     Single         70.0              No
# 1            1     Single        100.0              No
# 2            2   Multiple         60.0              No
# 3            3   Multiple        100.0              No
# 4            4   Multiple         60.0              No
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement
# 0                            No                            No
# 1                            No                            No
# 2                       Unknown                            No
# 3                            No                            No
# 4                            No                            No

# %% [markdown]
# **5. Create fact_fatalities Table**

# %%
fact_fatalities = df.merge(dim_date, on = ['Month', 'Year', 'Time', 'Time of Day', 'Holiday Flag', 'Weekend Flag'], how = 'left')
fact_fatalities = fact_fatalities.merge(dim_location, on = ['State', 'National Road Type', 'National Remoteness Areas 2021', 'SA4 Name 2021', 'National LGA Name 2021'], how = 'left')
fact_fatalities = fact_fatalities.merge(dim_person, on = ['Gender', 'Age Group', 'Road User'], how = 'left')
fact_fatalities = fact_fatalities.merge(dim_scenario, on = ['Crash Type', 'Speed Limit', 'Bus Involvement', 'Heavy Rigid Truck Involvement', 'Articulated Truck Involvement'], how = 'left')

# %%
fact_columns = [
    'Date ID', 
    'Location ID', 
    'Person ID', 
    'Scenario ID', 
    'Crash ID',    
    'Age',          
    'Speed Limit'   
]

fact_fatalities = fact_fatalities[fact_columns]
fact_fatalities.head()
# Out:
#    Date ID  Location ID  Person ID  Scenario ID       Crash ID   Age  \
# 0        0            0          0            0  5201106170079  46.0
# 1        1            1          1            1  4201105140046  19.0
# 2        2            2          2            2  1199410070402  35.0
# 3        3            3          3            3  3201212280255  38.0
# 4        4            3          4            4  3201110220178  28.0
#
#    Speed Limit
# 0         70.0
# 1        100.0
# 2         60.0
# 3        100.0
# 4         60.0
